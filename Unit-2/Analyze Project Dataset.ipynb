# %% [markdown]
# ## imports

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data = pd.read_csv("/content/drive/MyDrive/B-CODECRUNCH/spotify_songs.csv")

# %%
data
# Out:
#                      track_id  \
# 0      6f807x0ima9a1j3VPbc7VN
# 1      0r7CVbZTWZgbTCYdfa2P31
# 2      1z1Hg7Vb0AhHDiEmnDE79l
# 3      75FpbthrwQmzHlBJLuGdC7
# 4      1e8PAfcKUYoKkxPhrHqw4x
# ...                       ...
# 32828  7bxnKAamR3snQ1VGLuVfC1
# 32829  5Aevni09Em4575077nkWHz
# 32830  7ImMqPP3Q1yfUHvsdn7wEo
# 32831  2m69mhnfQ1Oq6lGtXuYhgX
# 32832  29zWqhca3zt5NsckZqDf6c
#
#                                               track_name      track_artist  \
# 0      I Don't Care (with Justin Bieber) - Loud Luxur...        Ed Sheeran
# 1                        Memories - Dillon Francis Remix          Maroon 5
# 2                        All the Time - Don Diablo Remix      Zara Larsson
# 3                      Call You Mine - Keanu Silva Remix  The Chainsmokers
# 4                Someone You Loved - Future Humans Remix     Lewis Capaldi
# ...                                                  ...               ...
# ...

# %%
data.columns
# Out:
# Index(['track_id', 'track_name', 'track_artist', 'track_popularity',
#        'track_album_id', 'track_album_name', 'track_album_release_date',
#        'playlist_name', 'playlist_id', 'playlist_genre', 'playlist_subgenre',
#        'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'duration_ms'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32833 entries, 0 to 32832
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   track_id                  32833 non-null  object
#  1   track_name                32828 non-null  object
#  2   track_artist              32828 non-null  object
#  3   track_popularity          32833 non-null  int64
#  4   track_album_id            32833 non-null  object
#  5   track_album_name          32828 non-null  object
#  6   track_album_release_date  32833 non-null  object
#  7   playlist_name             32833 non-null  object
#  8   playlist_id               32833 non-null  object
#  9   playlist_genre            32833 non-null  object
#  10  playlist_subgenre         32833 non-null  object
#  11  danceability              32833 non-null  float64
#  12  energy                    32833 non-null  float64
# ...

# %%
sns.scatterplot(data,x="tempo",y="loudness",hue="playlist_genre")
# Out:
# <Axes: xlabel='tempo', ylabel='loudness'>

# %%
data[["playlist_genre","playlist_subgenre"]]
# Out:
#       playlist_genre          playlist_subgenre
# 0                pop                  dance pop
# 1                pop                  dance pop
# 2                pop                  dance pop
# 3                pop                  dance pop
# 4                pop                  dance pop
# ...              ...                        ...
# 32828            edm  progressive electro house
# 32829            edm  progressive electro house
# 32830            edm  progressive electro house
# 32831            edm  progressive electro house
# 32832            edm  progressive electro house
#
# [32833 rows x 2 columns]

# %%
sns.pairplot(data[['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness','acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',"playlist_genre"]],hue="playlist_genre")
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
sns.countplot(data, x="playlist_genre",hue="playlist_genre")
# Out:
# <Axes: xlabel='playlist_genre', ylabel='count'>

# %%
fig, ax = plt.subplots(figsize=(50, 5))
sns.countplot(data, x="playlist_subgenre",hue="playlist_genre")
# Out:
# <Axes: xlabel='playlist_subgenre', ylabel='count'>

# %%
d1 = data.drop(["track_name","track_artist","track_album_id","track_album_name","track_album_release_date","playlist_id"],axis=1)

# %%
d1
# Out:
#                      track_id  track_popularity    playlist_name  \
# 0      6f807x0ima9a1j3VPbc7VN                66        Pop Remix
# 1      0r7CVbZTWZgbTCYdfa2P31                67        Pop Remix
# 2      1z1Hg7Vb0AhHDiEmnDE79l                70        Pop Remix
# 3      75FpbthrwQmzHlBJLuGdC7                60        Pop Remix
# 4      1e8PAfcKUYoKkxPhrHqw4x                69        Pop Remix
# ...                       ...               ...              ...
# 32828  7bxnKAamR3snQ1VGLuVfC1                42  ♥ EDM LOVE 2020
# 32829  5Aevni09Em4575077nkWHz                20  ♥ EDM LOVE 2020
# 32830  7ImMqPP3Q1yfUHvsdn7wEo                14  ♥ EDM LOVE 2020
# 32831  2m69mhnfQ1Oq6lGtXuYhgX                15  ♥ EDM LOVE 2020
# 32832  29zWqhca3zt5NsckZqDf6c                27  ♥ EDM LOVE 2020
#
#       playlist_genre          playlist_subgenre  danceability  energy  key  \
# 0                pop                  dance pop         0.748   0.916    6
# ...

# %%
d1.to_csv("/content/drive/MyDrive/B-CODECRUNCH/SpNew.csv")

# %%
d2,temp = train_test_split(d1,train_size=0.03)

# %%
d2
# Out:
#                      track_id  track_popularity  \
# 22842  2dLLR6qlu5UJ5gk0dKz0h3                78
# 14006  2nLtzopw4rPReszdYBJU6h                81
# 7509   5cwZFTdktFh5XjRglkqJYr                50
# 10486  3dhhGh3asfF8Aq1uHzkWy6                43
# 3552   0zx2Dq4YeAAjKcbPSS2DaQ                31
# ...                       ...               ...
# 25511  3wH3TWKBA9NCZinuBidD21                35
# 30108  7vfWgVGiLgnGbInU5lvSQg                17
# 621    36pYPsbeDZTNLFhDJbVv9b                61
# 30204  6WrI0LAC5M1Rw2MnX2ZvEg                97
# 9098   2eIRE17ugmqHEjDbXWCalr                38
#
#                                            playlist_name playlist_genre  \
# 22842  Ultimate Indie Presents... Best Indie Tracks o...            r&b
# 14006                                     Permanent Wave           rock
# 7509                                         Badass Rock            rap
# 10486                                        Trap Mojito            rap
# ...

# %%
sns.scatterplot(d2,x="tempo",y="loudness",hue="playlist_genre")
# Out:
# <Axes: xlabel='tempo', ylabel='loudness'>
