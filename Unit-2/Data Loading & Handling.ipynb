# %% [markdown]
# # Introduction

# %% [markdown]
# ## Imports

# %%
import pandas as pd
from google.colab import drive

# %% [markdown]
# - mount google drive

# %%
drive.mount('/content/drive')

# %% [markdown]
# ## Data Loading

# %% [markdown]
# - load dataset

# %%
data=pd.read_csv("/content/drive/MyDrive/B-CODECRUNCH/Salary_dataset.csv",index_col=0)

# %% [markdown]
# - print dataset

# %%
data #print(data)

# %% [markdown]
# - load different dataset

# %%
pd.read_csv("/content/sample_data/california_housing_test.csv")

# %% [markdown]
# - load different dataset from json file

# %%
data = pd.read_json("/content/sample_data/anscombe.json")

# %% [markdown]
# - print dataset

# %%
data #print(data)
