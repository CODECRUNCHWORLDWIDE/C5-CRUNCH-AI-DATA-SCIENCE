# %%
from sklearn.cluster import KMeans, DBSCAN
from sklearn.metrics import silhouette_score
from sklearn.mixture import GaussianMixture
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data = pd.read_csv("/content/drive/MyDrive/B-CODECRUNCH/spotify.csv")

# %%
data #print(data)
# Out:
#                      track_id  \
# 0      6f807x0ima9a1j3VPbc7VN
# 1      0r7CVbZTWZgbTCYdfa2P31
# 2      1z1Hg7Vb0AhHDiEmnDE79l
# 3      75FpbthrwQmzHlBJLuGdC7
# 4      1e8PAfcKUYoKkxPhrHqw4x
# ...                       ...
# 32828  7bxnKAamR3snQ1VGLuVfC1
# 32829  5Aevni09Em4575077nkWHz
# 32830  7ImMqPP3Q1yfUHvsdn7wEo
# 32831  2m69mhnfQ1Oq6lGtXuYhgX
# 32832  29zWqhca3zt5NsckZqDf6c
#
#                                               track_name      track_artist  \
# 0      I Don't Care (with Justin Bieber) - Loud Luxur...        Ed Sheeran
# 1                        Memories - Dillon Francis Remix          Maroon 5
# 2                        All the Time - Don Diablo Remix      Zara Larsson
# 3                      Call You Mine - Keanu Silva Remix  The Chainsmokers
# 4                Someone You Loved - Future Humans Remix     Lewis Capaldi
# ...                                                  ...               ...
# ...

# %%
X = data[["valence","energy"]]

# %%
X #print(X)
# Out:
#        valence  energy
# 0       0.5180   0.916
# 1       0.6930   0.815
# 2       0.6130   0.931
# 3       0.2770   0.930
# 4       0.7250   0.833
# ...        ...     ...
# 32828   0.2100   0.922
# 32829   0.4000   0.786
# 32830   0.4360   0.821
# 32831   0.3080   0.888
# 32832   0.0894   0.884
#
# [32833 rows x 2 columns]

# %%
cls = KMeans(n_clusters=2)

# %%
cls.fit(X)
# Out:
# KMeans(n_clusters=2)

# %%
labels = cls.labels_
centroid = cls.cluster_centers_
centroid
# Out:
# array([[0.70286375, 0.73883772],
#        [0.31455642, 0.65762663]])

# %%
plt.scatter(X["valence"],X["energy"], c=labels,cmap="rainbow")
plt.scatter(centroid[:,0],centroid[:,0],marker='x',color='black',s=200)
plt.scatter(0.25,0.75,marker='X',color="green",s=300)
plt.xlabel("valence")
plt.ylabel("energy")
# plt.show()
# Out:
# Text(0, 0.5, 'energy')

# %%
cls = DBSCAN(eps=0.5, min_samples=4)
cls.fit(X)
plt.scatter(X["valence"],X["energy"], c=cls.labels_,cmap="rainbow")

# %%
GM = GaussianMixture()
GM.fit(X)
# Out:
# GaussianMixture()

# %%
GM.means_
# Out:
# array([[0.51056097, 0.69861927]])

# %%
plt.scatter(X["valence"],X["energy"], c=cls.labels_,cmap="rainbow")
plt.scatter(GM.means_[:,0],GM.means_[:,1],marker='x',color='black',s=200)
